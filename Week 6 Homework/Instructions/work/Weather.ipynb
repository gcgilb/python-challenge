# %%
# Dependencies
import json
import requests
import pandas as pd
from citipy import citipy
from config import api_key
import matplotlib.pyplot as plt
import random

# %%
cities = []
city1 = []

for x in range(1500):
    
    lat =(random.randint(-90.00,90.00))
    lon =(random.randint(-180,180))
    
    cities = citipy.nearest_city(lat, lon)
    city1.append(cities.city_name)

# %%
# Save config information.
url = "http://api.openweathermap.org/data/2.5/weather?"
#url = "http://api.openweathermap.org/data/2.5/weather?" #lat={lat}&lon={lon}
units = "imperial"

# Build partial query URL
query_url = f"{url}appid={api_key}&units={units}&q="

# %%
no_dupes = [x for n, x in enumerate(city1) if x not in city1[:n]]
#print(no_dupes)

# %%
#cities = ['green river', 'hasaki', 'lavrentiya', 'rikitea', 'auki', 'clifton', 'kruisfontein', 'hithadhoo', 'kaitangata', 'rikitea', 'qasigiannguit', 'upernavik', 'new norfolk', 'katangli', 'san joaquin', 'georgetown', 'belushya guba', 'flinders', 'hobart', 'dunedin', 'hasaki', 'tuatapere', 'severo-kurilsk', 'taolanaro', 'nanma', 'east london', 'albany', 'vila velha', 'buchanan', 'punta arenas', 'uruacu', 'qaanaaq', 'severo-kurilsk', 'busselton', 'georgetown', 'pine bluff', 'new norfolk', 'hobart', 'busselton', 'kodiak', 'nikolskoye', 'avarua', 'omboue', 'port moresby', 'lagoa', 'bandarbeyla', 'ribeira grande', 'busselton', 'toliary', 'vaini', 'khatanga', 'arlit', 'codrington', 'pathein', 'ilulissat', 'rikitea', 'cururupu', 'kodiak', 'kodiak', 'cayenne', 'constitucion', 'vaini', 'utiroa', 'castro', 'lazaro cardenas', 'bredasdorp', 'rikitea', 'barrow', 'vaini', 'mezen', 'hilo', 'clyde river', 'mashhad', 'kununurra', 'rikitea', 'rikitea', 'zuwarah', 'barentsburg', 'sola', 'mocuba', 'belushya guba', 'ahipara', 'pisco', 'point fortin', 'sarandi', 'new norfolk', 'busselton', 'kodiak', 'mys shmidta', 'adrar', 'airai', 'twentynine palms', 'illoqqortoormiut', 'mehamn', 'nikolskoye', 'sisimiut', 'hermanus', 'haines junction', 'nikolskoye', 'ponta do sol']
count = 0
cities = city1


#no_dupes = [x for n, x in enumerate(cities) if x not in cities[:n]]
#print(no_dupes)

# set up lists to hold reponse info

name = []
lat = []
lon = []
temp = []
hum = []
cloud = []
wind = []
date = []
cty = []
number = []

#for time in no_dupes:
            #raw_time = time["dt"]
            #print(raw_time)

# %%
# Loop through the list of cities and perform a request for data on each
for city in no_dupes:
   
    try:    
        response = requests.get(query_url + city).json()
        lat.append(response['coord']['lat'])
        temp.append(response['main']['temp_max'])
        hum.append(response['main']['humidity'])
        cloud.append(response['clouds']['all'])
        wind.append(response['wind']['speed'])
        date.append(response['dt'])
        name.append(response['name'])
        lon.append(response['coord']['lon'])
        cty.append(response['sys']['country'])
        number=(response['id'])
        
        print(city, number)
       
        
    except (KeyError):
        
        count + 1
# Out:
# chokurdakh 2126123
# petropavlovsk-kamchatskiy 2122104
# punta arenas 3874787
# barrow 3833859
# klaksvik 2618795
# north myrtle beach 4589446
# esperance 3573739
# przasnysz 761218
# muros 3115824
# bethel 5880568
# baherden 162158
# severo-kurilsk 2121385
# ushuaia 3833367
# cape town 3369157
# mataura 6201424
# nizwa 286987
# thai binh 1566346
# nouakchott 2377450
# bubaque 2374583
# carnarvon 1014034
# arraial do cabo 3471451
# atuona 4020109
# provideniya 4031574
# bredasdorp 1015776
# kamaishi 2112444
# taicheng 1793700
# lebu 344979
# castro 3896218
# tuktoyaktuk 6170031
# tiksi 2015306
# yar-sale 1486321
# shakawe 933077
# rikitea 4030556
# mahebourg 934322
# nuuk 3421319
# coremas 3401725
# busselton 2075265
# port blair 1259385
# christchurch 2192362
# petropavl 1520172
# port lincoln 2063036
# maiduguri 2331447
# qaanaaq 3831208
# nanakuli 5851349
# carutapera 3402648
# katsuura 1865309
# dikson 1507390
# boda 1185141
# las palmas 3691474
# qaqortoq 3420846
# port alfred 964432
# ribeira grande 3372707
# inta 1505579
# khatanga 2022572
# saskylakh 2017155
# hilo 5855927
# arman 2127060
# los llanos de aridane 2514651
# hobart 2163355
# new norfolk 2155415
# rawson 3839307
# tilichiki 2120591
# sorland 3137469
# cap malheureux 934649
# mehran 124291
# longyearbyen 2729907
# narsaq 3421719
# alur 1262794
# chapais 5919850
# pevek 2122090
# bluff 2175403
# puerto ayora 3652764
# luena 3347719
# bathsheba 3374083
# butaritari 2110227
# aden 415189
# prince rupert 6113406
# sale 2638678
# ola 2122574
# talnakh 1490256
# georgetown 3378644
# ilulissat 3423146
# avarua 4035715
# pauini 3662927
# kodiak 4407665
# iranshahr 1160939
# kavieng 2094342
# honiara 2108502
# hermanus 3366880
# albany 5106834
# kushiro 2129072
# alofi 4036284
# sao filipe 3374210
# geraldton 5960603
# lorengau 2092164
# manado 1636544
# kapaa 5848280
# hualmay 3939761
# bull savanna 3491161
# fort nelson 5955902
# dicabisagan 1715015
# hithadhoo 1282256
# waipawa 2185329
# aguimes 2522325
# beyneu 610298
# east london 1006984
# storforshei 3145614
# tucuman 3934608
# lazaro cardenas 3996234
# lagoa 2267254
# quang ngai 1568770
# vestmannaeyjar 3412093
# jinzhou 2036427
# suarez 3667772
# jamestown 2069194
# rio claro 3451234
# touros 3386213
# vardo 4372777
# bereda 3105522
# bloemfontein 1018725
# kuandian 2036283
# ondjiva 3346821
# walvis bay 3359638
# san policarpo 1688696
# guhagar 1270779
# tres arroyos 3833859
# lusambo 210379
# nome 4732862
# kardla 588335
# torbay 6167817
# kudahuvadhoo 1337607
# tura 1254046
# san patricio 3437029
# ossora 2122389
# hamilton 3573197
# leningradskiy 2123814
# vaini 1273574
# hohhot 2036892
# cabo san lucas 3985710
# port elizabeth 4501427
# whitehorse 6180550
# mar del plata 3863379
# mehamn 778707
# kapit 1737185
# alice springs 2077895
# gushikawa 1863495
# bilibino 2126682
# souillac 3026644
# margate 2158744
# araouane 2460954
# stokmarknes 3136690
# samarai 2132606
# husavik 5961417
# japura 1642773
# san quintin 1688687
# petaluma 5382232
# celestun 3531368
# harqalah 172955
# saldanha 2737599
# tansen 1282714
# rancho palos verdes 5386035
# klyuchevskiy 2021980
# mountain home 5601615
# lata 1253628
# isangel 2136825
# airai 1651810
# saint george 262462
# victoria 1733782
# graham 4468525
# mount gambier 2156643
# dandong 2037886
# fort pierce 4156018
# roma 6539761
# mathathane 933383
# eureka 5563397
# laurel 5661766
# kuusamo 649924
# port augusta 2063056
# aleppo 170063
# thompson 6165406
# bambous virieux 1106677
# san fernando 3871286
# brae 2654970
# yellowknife 6185377
# naze 2337542
# kaitangata 2208248
# te anau 2181625
# montepuez 1037125
# guerrero negro 4021858
# nevsehir 303831
# nisia floresta 3393922
# ahipara 2194098
# goryachegorsk 1491519
# victor harbor 2059470
# cherskiy 2126199
# saint-philippe 6138908
# itarema 3393692
# sakaraha 1057095
# richards bay 962367
# rio gallegos 3838859
# egvekinot 4031742
# lavrentiya 4031637
# sept-iles 6144312
# hobyo 57000
# swan hill 2147756
# tadine 2138285
# batavia 5108093
# karratha 6620339
# inuvik 5983607
# leh 1264976
# punta alta 3429886
# tsaratanana 1055059
# saint anthony 5606187
# peresichna 697676
# ponta do sol 3453439
# kruisfontein 986717
# champerico 3530097
# sorsk 1491360
# khandyga 2022773
# nikolskoye 546105
# plettenberg bay 964712
# doka 376332
# maniitsoq 3421982
# tasiilaq 3424607
# moron 3631878
# turukhansk 1488903
# upernavik 3418910
# oranjestad 3577154
# corinto 3465512
# grindavik 3416888
# kulhudhuffushi 1337613
# bartica 3379507
# nokaneng 933211
# upington 945945
# adrar 2508813
# portland 5746545
# havoysund 779622
# clarence town 2171465
# vila franca do campo 3372472
# eura 660080
# angermunde 2956093
# laguna 4013704
# boralday 1526384
# monrovia 2274895
# dudinka 1507116
# iqaluit 5983720
# necochea 3430443
# yulara 6355222
# vallenar 3868633
# bontang 1648186
# dunedin 2191562
# yuxia 1785572
# luoyang 1801792
# lamu 1623890
# fortuna 2517679
# kargil 1267776
# marin 662334
# baykit 1510689
# roald 3141667
# lasa 146639
# port moresby 2088122
# caravelas 3466980
# puerto carreno 3671519
# hofn 2630299
# venustiano carranza 3827407
# atambua 1651103
# lagos 2332459
# college 5859699
# bam 141736
# ust-nera 2120048
# luderitz 3355672
# mazatlan 3996322
# manzhouli 2035836
# tuy hoa 1563281
# palmer 2067070
# bambanglipuro 1650434
# pangai 4032369
# haines junction 5969025
# springfield 4409896
# mackay 5921525
# kieta 2094027
# pacific grove 5380437
# leczyca 3093726
# vila velha 6320062
# clyde river 5924351
# vao 588365
# valleyview 6173220
# lyantonde 229599
# sangmelima 2222230
# chuy 3443061
# krasnyy kholm 541704
# gornopravdinsk 1506268
# cayenne 3382160
# manaus 3663517
# tessalit 2449893
# munster 2867542
# grand gaube 934479
# nanortalik 3421765
# truth or consequences 5495292
# aksu 1524298
# sur 286245
# cidreira 3466165
# mayo 6068416
# madang 2091996
# leshukonskoye 535839
# hami 1529484
# chingirlau 610091
# grand-lahou 2288105
# mikhaylovskoye 526749
# renqiu 1797181
# garowe 58933
# vila praia de ancora 2732516
# divnogorsk 1507379
# pervouralsk 510808
# port macquarie 2152659
# aksarka 1512019
# lillooet 6945979
# carmelo 3443341
# biak 1637001
# purwodadi 1630333
# homer 5864145
# miracema do tocantins 3384937
# maumere 1635815
# narragansett 5225535
# dwarka 1273294
# harper 4696310
# tanout 2439155
# troitsko-pechorsk 481548
# aripuana 3665202
# ostrovnoy 556268
# ust-uda 2013865
# talaya 1485724
# san cristobal 3652462
# santiago del estero 3835869
# kavaratti 1267390
# chiang rai 1153669
# bajos de haina 3512128
# port-gentil 2396518
# kaputa 176758
# pangody 1495626
# tarbagatay 2015545
# constitucion 4011743
# tulle 2971482
# komsomolskiy 1486910
# aransas pass 4671141
# pokhara 1282898
# henties bay 3356832
# dodge city 5445298
# ushtobe 1517637
# oudtshoorn 967106
# rodrigues alves 3665210
# atikokan 5888001
# great bend 4272340
# visnes 3131500
# ancud 3899695
# san luis 3837056
# sanming 1796663
# agustin codazzi 3792383
# durban 3016194
# kanigoro 1641497
# gravatai 3462089
# simpang 1734586
# pochutla 3517970
# saint-augustin 3031582
# two hills 6171332
# nadym 1498087
# cururupu 3401148
# buala 2109528
# avera 4231997
# qandala 53157
# mangan 1263776
# segou 2252081
# meulaboh 1214488
# emirdag 315621
# codrington 2160063
# sao joao da barra 3448903
# aklavik 5882953
# wanning 3220813
# sola 3137942
# asimion 264501
# jiuquan 1280957
# ngaoundere 2224827
# trairi 3386177
# salinopolis 3389822
# tazovskiy 1489853
# faanui 4034551
# camacha 2270385
# pangnirtung 6096551
# timra 2669047
# lewistown 4899665
# arkhipo-osipovka 580969
# harnosand 2707684
# wellington 2179537
# mazamari 3935102
# lompoc 5367788
# berlevag 780687
# beringovskiy 2126710
# bonthe 2409914
# kankan 2419992
# assare 3407010
# salalah 286621
# natal 3394023
# bodden town 3580733
# berezovyy 2026786
# voyvozh 471308
# monster 2750630
# asadabad 142872
# pahrump 5509851
# kwekwe 888710
# hambantota 1244926
# morlaix 2991772
# det udom 1610940
# huarmey 3939168
# vuktyl 470905
# pella 4870915
# tuatapere 2180815
# hirara 1862505
# norman wells 6089245
# malindi 187968
# liberal 5445820
# choix 4014109
# shestakovo 2016733
# twentynine palms 5404198
# owosso 5004792
# nelson bay 2155562
# nuqui 3673690
# garmsar 32723
# troianul 664591
# zhezkazgan 1516589
# temirtau 1518262
# bure 2317887
# kaihua 1789001
# nara 1855612
# padang 1633419
# nikki 2392505
# kassala 372753
# prieska 964090
# juneau 5554072
# khani 610864
# arshan 75518
# kidal 2455290
# venice 4176380
# cambrils 3126888
# nueva loja 3655185
# suba 1800475
# karasjok 779350
# rovnoye 501091
# emporia 4271086
# amboasary 1081790
# santa maria del oro 3984078
# monterey 5374361
# hun 2790471
# tevriz 1489661
# lucea 3489657
# griffith 2164422
# ayan 749747
# thomaston 4226364
# miles city 5666176
# madison 5261457
# visby 2662689
# nhulunbuy 2064735
# coquimbo 3893629
# marabba 370510
# deer lake 5937252
# hovd 7626384
# viedma 3832899
# verkhnevilyuysk 2013639
# povenets 505820
# san carlos de bariloche 7647007
# magistralnyy 2020584
# kibondo 157960
# boali 2388720
# koson 1217007
# mangrol 1263751
# shache 1280037
# viljoenskroon 943960
# shenjiamen 1795632
# ulu-telyak 479198
# kangasala 654441
# fethiye 314967
# senanga 898947
# vostok 2013279
# nakhon ratchasima 1608529
# zheleznodorozhnyy 463355
# gubkinskiy 1539209
# coihaique 3894426
# sendafa 328880
# acari 3390864
# aasiaat 3424901
# elizabeth city 4465088
# novobirilyussy 1508260
# verkhoyansk 2013465
# sabha 2212775
# gizo 6693679
# ericeira 2268563
# leona vicario 3822745
# ngunguru 2186111
# vikulovo 557754
# matagami 2335713
# okhotsk 2122605
# tello 3667323
# russkiy aktash 583573
# jacareacanga 3397763
# glendive 5654391
# gat 2249901
# krasnyy kut 474059
# samana 3655185
# las tunas 3550598
# makakilo city 5850554
# nemuro 2128975
# ust-kuyga 2013921
# new waterford 5164449
# hasaki 2112802
# iberia 3938531
# saint-ambroise 3025602
# diu 1272502
# varhaug 3132644
# ponta delgada 3372783
# quatre cocos 1106643
# san joaquin 1689597
# betare oya 2234339
# kokopo 2093685
# kamenka 553725
# yerbogachen 2012956
# lerwick 2644605
# orlovskiy 514796
# sioux lookout 6148373
# tongliao 2034400
# koraput 1266128
# krabi 1152633
# fonte boa 3664207
# powell river 6112608
# kungurtug 1501377
# selenduma 2017063
# zabol 1113217
# diveyevo 566165
# beysehir 321191
# mitsamiouli 921786
# mumbwa 904422
# mustasaari 651301
# blagoveshchenka 1509999
# makokou 2399371
# usinsk 863061
# tevaitoa 4033375
# la tuque 6050416
# cabra 2520645
# ocean city 4166723
# batagay-alyta 2027042
# damphu 1337281
# rocha 3440777
# marawi 1701054
# sveti nikole 785201
# ulaangom 1515029
# byron bay 2172880
# xicotencatl 3483063
# mana 789988
# najran 103630
# fairbanks 5861897

# %%
#print(f"The temperature information received is: {temp}")
#print(f"The humidity information received is: {hum}")
#print(f"The cloudiness information received is: {cloud}")
#print(f"The wind speed information received is: {wind}")
#print(count)

# %%
# create a data frame from cities, lat, and temp
weather = {
    "City": name,
       "Lat": lat,
    "Max Temp": temp,
    "Cloudiness": cloud,
    "Wind Speed": wind,
    "Humidity": hum,
    "Country": cty,
    "Date": date,
    "Lng": lon
    
    }
weather_data = pd.DataFrame(weather)
weather_data.head()
# Out:
#                         City  Cloudiness Country        Date  Humidity    Lat  \
# 0                 Chokurdakh           0      RU  1529523410        84  70.62
# 1  Petropavlovsk-Kamchatskiy          32      RU  1529521200        93  53.05
# 2               Punta Arenas          75      CL  1529521200        64 -53.16
# 3                     Barrow           0      AR  1529524543        53 -38.31
# 4                   Klaksvik          76      FO  1529520600        70  62.23
#
#       Lng  Max Temp  Wind Speed
# 0  147.90     42.78        9.42
# 1  158.65     48.20        2.26
# 2  -70.91     37.40       28.86
# 3  -60.23     57.54       11.43
# 4   -6.59     48.20       13.87

# %%
weather_data.count()
# Out:
# City          558
# Cloudiness    558
# Country       558
# Date          558
# Humidity      558
# Lat           558
# Lng           558
# Max Temp      558
# Wind Speed    558
# dtype: int64

# %%
# Build a scatter plot for each data type
plt.scatter(weather_data["Lat"], weather_data["Max Temp"], marker="o")

# Incorporate the other graph properties
plt.title("City Latitude vs. Max Temperature")
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)

# Show plot
plt.show()

# %%
# Build a scatter plot for each data type
plt.scatter(weather_data["Lat"], weather_data["Humidity"], marker="o")

# Incorporate the other graph properties
plt.title("City Latitude vs. Humidity")
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Show plot
plt.show()

# %%
# Build a scatter plot for each data type
plt.scatter(weather_data["Lat"], weather_data["Cloudiness"], marker="o")

# Incorporate the other graph properties
plt.title("City Latitude vs. Cloudiness")
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Show plot
plt.show()

# %%
# Build a scatter plot for each data type
plt.scatter(weather_data["Lat"], weather_data["Wind Speed"], marker="o")

# Incorporate the other graph properties
plt.title("City Latitude vs. Wind Speed")
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid(True)

# Show plot
plt.show()
